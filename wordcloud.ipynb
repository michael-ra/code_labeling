# %% [markdown]
# <a href="https://colab.research.google.com/github/analyticswithadam/Python/blob/main/YouTubeComments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv("/Users/Johannes/Desktop/WiSe2023_2024/AI_public_discourse/all_comments.csv", sep=';')

# %%
first_500_comments = df.head(500)
first_500_comments.head(10)
# Out:
#                author            updated_at like_count  \
# 0     @RealEagleScout  2023-12-01T12:48:52Z          0
# 1  @juliemccannon2908  2023-12-01T10:06:51Z          1
# 2            @c431inf  2023-12-01T01:25:59Z          1
# 3      @johnluber9957  2023-11-30T20:47:03Z          3
# 4      @wades_world22  2023-11-30T18:28:57Z          1
# 5    @user-eg7hb7od2v  2023-11-30T17:56:54Z          0
# 6       @harishpadale  2023-11-30T04:42:44Z          1
# 7   @ivabuckley-wn6ig  2023-11-29T22:16:13Z          0
# 8        @CSGdesign01  2023-11-29T10:43:28Z          3
# 9      @lucianene7741  2023-11-28T22:20:33Z          2
#
#                                                 text     video_id public
# 0  Bustin a move, like Gregory Hines, or.. Melody...  fn3KWM1kuAw   True
# 1  I wish I could afford a Spot. I would love to ...  fn3KWM1kuAw   True
# 2                             Amazing and disturbing  fn3KWM1kuAw   True
# ...

# %%
first_500_comments = first_500_comments.drop("public", axis=1)
first_500_comments = first_500_comments.drop("video_id", axis=1)
first_500_comments = first_500_comments.drop("updated_at", axis=1)
first_500_comments = first_500_comments.drop("like_count", axis=1)


first_500_comments['Vermenschlichung'] = '0'
first_500_comments['Positive_Bewertung'] = '0'
first_500_comments['Negative_Bewertung'] = '0'
first_500_comments['Überschätzung_Automatisiert'] = '0'
first_500_comments['Überschätzung_Fehleranfälligkeit'] = '0'
first_500_comments['Notizen'] = '-'



first_500_comments.head(10)
# Out:
#                author                                               text  \
# 0     @RealEagleScout  Bustin a move, like Gregory Hines, or.. Melody...
# 1  @juliemccannon2908  I wish I could afford a Spot. I would love to ...
# 2            @c431inf                             Amazing and disturbing
# 3      @johnluber9957  as far as I can tell, i see three outcomes.\n\...
# 4      @wades_world22                                    just incredible
# 5    @user-eg7hb7od2v                       Ну, вот  и артистов не надо.
# 6       @harishpadale  SCIENCE START DO NOT THINK OFF Countries RELAT...
# 7   @ivabuckley-wn6ig                     Amazing, can I have one ☝️ lol
# 8        @CSGdesign01                                   Not long now....
# 9      @lucianene7741                  Can you make a robot play guitar?
#
#   Vermenschlichung Positive_Bewertung Negative_Bewertung  \
# 0                0                  0                  0
# ...

# %%
first_500_comments.to_csv('first_500_comments.csv', sep=';', index=False)

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text =  df['text'].str.cat(sep=', ')

# Generate a word cloud image
wordcloud_example = WordCloud().generate(text)

plt.imshow(wordcloud_example, interpolation="bilinear")
plt.show()
